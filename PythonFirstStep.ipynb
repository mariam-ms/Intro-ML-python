# %% [markdown]
# # Python Learning steps
# this notebook contains simple example of using *jupyter notebook* and *python three*.

# %% [markdown]
# ## Example 1: Hello, world

# %%
my_name = "Mar"
hello_statement="Hello , "+my_name
print(hello_statement, end="\n\n")
# Out:
# Hello , Mar

# %% [markdown]
# ## Example 2 : for loop

# %%
x=10
for i in range(1,5):
    x=x+i
    print("i={0} x={1}".format(i, x))
# Out:
# i=1 x=11
# i=2 x=13
# i=3 x=16
# i=4 x=20
